# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the data
df = pd.read_csv('src/data/count_data.csv')
df.head(3)
# Change the column names
df.columns = ['Año-mes', 'año', 'mes', 'Total de puntos', 'Total de puntos sin duplicados']

# %%
# Plot the data
df.plot(kind='bar',
        stacked=False, color=['gray', 'red'],
        x='Año-mes', y=['Total de puntos', 'Total de puntos sin duplicados'], figsize=(12, 6))

# Add labels
plt.xlabel('Año-mes')
plt.ylabel('Cantidad de puntos')
plt.title('Distribución Mensual de Puntos Totales y Sin Duplicados para Evaluación')
plt.show()
